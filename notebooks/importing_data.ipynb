# %% [markdown]
# ## Importing Data
#
# This notebook serves as a step-by-step guide to importing match and event data from the official StatsBomb repository. It documents the exact process used to retrieve, filter, and store the raw data for further analysis.
#
# We use the `statsbombpy` library, which provides a **Pythonic interface** to interact with StatsBomb's open-data GitHub repository. It abstracts the underlying JSON structure and URL handling, allowing straightforward access to competitions, matches, events, and lineups through simple function calls.

# %%
import pandas as pd
from statsbombpy import sb

# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)

from src.constants import *

# module made to get data
import src.get_data as gd

# %%
# to suppress Authentication warnings
from statsbombpy.api_client import NoAuthWarning
import warnings
warnings.filterwarnings("ignore", category=NoAuthWarning)

# %%
# for better visibility and showing all the columns
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### 1. Competitions Data

# %%
# Load and Filter Competitions
competitions = sb.competitions()

# Filter: keep only male competitions
competitions = competitions[competitions['competition_gender']=='male'].sort_values('season_name', ascending=False)

# Filter: keep seasons from 2014 onward
competitions = competitions[competitions['season_name']>'2014']

# Filter: exclude Indian Super League
competitions = competitions[competitions['competition_name']!='Indian Super league']

# %%
# Drop unnecessary columns
competitions.drop(COMPETITIONS_COLUMNS_DROP,
                  axis=1,
                  inplace=True)

# Reset index after filtering
competitions.reset_index(drop=True,
                         inplace=True)

# %%
competitions
# Out:
#     competition_id  season_id              country_name  \
# 0              223        282             South America
# 1               55        282                    Europe
# 2                9        281                   Germany
# 3               44        107  United States of America
# 4             1267        107                    Africa
# 5                7        235                    France
# 6               43        106             International
# 7                7        108                    France
# 8               11         90                     Spain
# 9               55         43                    Europe
# 10              11         42                     Spain
# 11              11          4                     Spain
# 12              16          4                    Europe
# 13              43          3             International
# 14              16          1                    Europe
# 15              11          1                     Spain
# 16              11          2                     Spain
# 17              16          2                    Europe
# 18               2         27                   England
# 19               9         27                   Germany
# 20              11         27                     Spain
# 21               7         27                    France
# 22              16         27                    Europe
# 23              12         27                     Italy
# 24              16         26                    Europe
# 25              11         26                     Spain
#
#           competition_name  competition_international season_name
# 0             Copa America                       True        2024
# 1                UEFA Euro                       True        2024
# 2            1. Bundesliga                      False   2023/2024
# 3      Major League Soccer                      False        2023
# 4   African Cup of Nations                       True        2023
# 5                  Ligue 1                      False   2022/2023
# 6           FIFA World Cup                       True        2022
# 7                  Ligue 1                      False   2021/2022
# 8                  La Liga                      False   2020/2021
# 9                UEFA Euro                       True        2020
# 10                 La Liga                      False   2019/2020
# 11                 La Liga                      False   2018/2019
# 12        Champions League                      False   2018/2019
# 13          FIFA World Cup                       True        2018
# 14        Champions League                      False   2017/2018
# 15                 La Liga                      False   2017/2018
# 16                 La Liga                      False   2016/2017
# 17        Champions League                      False   2016/2017
# 18          Premier League                      False   2015/2016
# 19           1. Bundesliga                      False   2015/2016
# 20                 La Liga                      False   2015/2016
# 21                 Ligue 1                      False   2015/2016
# 22        Champions League                      False   2015/2016
# 23                 Serie A                      False   2015/2016
# 24        Champions League                      False   2014/2015
# 25                 La Liga                      False   2014/2015

# %% [markdown]
# We end up with 26 leagues across various competitions

# %%
competitions.to_csv('../data/competitions.csv', index=False)

# %% [markdown]
# ### 2. Matches

# %%
df_matches = gd.get_matches(competitions)
df_matches.head()
# Out:
#    match_id  match_date      kick_off                   competition season  \
# 0   3943077  2024-07-15  04:15:00.000  South America - Copa America   2024
# 1   3943076  2024-07-14  03:00:00.000  South America - Copa America   2024
# 2   3942852  2024-07-11  03:00:00.000  South America - Copa America   2024
# 3   3942785  2024-07-10  03:00:00.000  South America - Copa America   2024
# 4   3942416  2024-07-07  01:00:00.000  South America - Copa America   2024
#
#    home_team away_team  home_score  away_score  match_week competition_stage  \
# 0  Argentina  Colombia           1           0           6             Final
# 1     Canada   Uruguay           2           2           6   3rd Place Final
# 2    Uruguay  Colombia           0           1           5       Semi-finals
# 3  Argentina    Canada           2           0           5       Semi-finals
# 4   Colombia    Panama           5           0           4    Quarter-finals
#
#                    stadium                        referee  \
# 0        Hard Rock Stadium                  Raphael Claus
# 1  Bank of America Stadium                 Alexis Herrera
# 2  Bank of America Stadium  César Arturo Ramos Palazuelos
# 3          MetLife Stadium               Piero Maza Gomez
# 4       State Farm Stadium               Maurizio Mariani
#
#                     home_managers                   away_managers data_version
# 0        Lionel Sebastián Scaloni          Néstor Gabriel Lorenzo        1.1.0
# 1                    Jesse Marsch  Marcelo Alberto Bielsa Caldera        1.1.0
# 2  Marcelo Alberto Bielsa Caldera          Néstor Gabriel Lorenzo        1.1.0
# 3        Lionel Sebastián Scaloni                    Jesse Marsch        1.1.0
# 4          Néstor Gabriel Lorenzo       Thomas Christiansen Tarín        1.1.0

# %%
df_matches.groupby('competition').size()
# Out:
# competition
# Africa - African Cup of Nations                    52
# England - Premier League                          380
# Europe - Champions League                           5
# Europe - UEFA Euro                                102
# France - Ligue 1                                  435
# Germany - 1. Bundesliga                           340
# International - FIFA World Cup                    128
# Italy - Serie A                                   380
# South America - Copa America                       32
# Spain - La Liga                                   590
# United States of America - Major League Soccer      6
# dtype: int64

# %%
df_matches.to_csv('../data/matches.csv', index=False)

# %% [markdown]
# ### 3. Lineups
#
# <i>Although will not be used for this project</i>

# %%
df_lineups = gd.get_lineups(df_matches)
# Out:
# [0] Processed match_id 3943077
# [50] Processed match_id 3930179
# [100] Processed match_id 3895320
# [150] Processed match_id 3920412
# [200] Processed match_id 3837752
# [250] Processed match_id 3857292
# [300] Processed match_id 3773631
# [350] Processed match_id 3794692
# [400] Processed match_id 303696
# [450] Processed match_id 22912
# [500] Processed match_id 7572
# [550] Processed match_id 9754
# [600] Processed match_id 3754053
# [650] Processed match_id 3754093
# [700] Processed match_id 3754223
# [750] Processed match_id 3754343
# [800] Processed match_id 3754016
# [850] Processed match_id 3754139
# [900] Processed match_id 3754239
# [950] Processed match_id 3754333
# [1000] Processed match_id 3890545
# [1050] Processed match_id 3890492
# [1100] Processed match_id 3890442
# [1150] Processed match_id 3890387
# [1200] Processed match_id 3890335
# [1250] Processed match_id 3890284
# [1300] Processed match_id 3825839
# [1350] Processed match_id 3825803
# [1400] Processed match_id 3825711
# [1450] Processed match_id 3825623
# [1500] Processed match_id 3825679
# [1550] Processed match_id 3825719
# [1600] Processed match_id 3825586
# [1650] Processed match_id 266490
# [1700] Processed match_id 3901231
# [1750] Processed match_id 3901176
# [1800] Processed match_id 3900600
# [1850] Processed match_id 3900505
# [1900] Processed match_id 3900562
# [1950] Processed match_id 3829509
# [2000] Processed match_id 3829449
# [2050] Processed match_id 3879579
# [2100] Processed match_id 3879732
# [2150] Processed match_id 3879846
# [2200] Processed match_id 3879765
# [2250] Processed match_id 3879689
# [2300] Processed match_id 3879634
# [2350] Processed match_id 3879569
# [2400] Processed match_id 3878550

# %%
df_lineups.head()
# Out:
#    player_id                      player_name     player_nickname  \
# 0       2995  Ángel Fabián Di María Hernández      Ángel Di María
# 1       3090          Nicolás Hernán Otamendi    Nicolás Otamendi
# 2       3313                 Giovani Lo Celso                None
# 3       5503   Lionel Andrés Messi Cuccittini        Lionel Messi
# 4       5507     Nicolás Alejandro Tagliafico  Nicolás Tagliafico
#
#    jersey_number    country  \
# 0             11  Argentina
# 1             19  Argentina
# 2             16  Argentina
# 3             10  Argentina
# 4              3  Argentina
#
#                                                cards  \
# 0                                                 []
# 1                                                 []
# 2  [{'time': '11:26', 'card_type': 'Yellow Card',...
# 3                                                 []
# 4                                                 []
#
#                                            positions  match_id
# 0  [{'position_id': 12, 'position': 'Right Midfie...   3943077
# 1  [{'position_id': 12, 'position': 'Right Midfie...   3943077
# 2  [{'position_id': 11, 'position': 'Left Defensi...   3943077
# 3  [{'position_id': 22, 'position': 'Right Center...   3943077
# 4  [{'position_id': 6, 'position': 'Left Back', '...   3943077

# %%
df_lineups.to_csv('../data/lineups.csv', index=False)

# %% [markdown]
# ### 4. Events

# %%
start_i = 0
end_i = 10

df_events = gd.get_events(df_matches, EVENT_COLUMNS_SELECT, start_i, end_i)
# Out:
# [0] Processed match_id=3943077 (4108 rows)
# Completed 10 matches.
# Total rows: 31102
# Columns: 122
# Null match_id values: 0

# %%
df_events[df_events['type']=='Shot'].shape[0]
# Out:
# 274

# %%
df_events.to_csv(f'../data/events_{start_i}_{end_i}.csv', index=False, sep=';')

# %% [markdown]
# ### 5. Frames

# %%
df_frames = gd.get_frames(df_matches)

# %%
df_frames.to_csv('../data/frames.csv', index=False)
