# %% [markdown]
# ## Importing Data
#
# This notebook serves as a step-by-step guide to importing match and event data from the official StatsBomb repository. It documents the exact process used to retrieve, filter, and store the raw data for further analysis.
#
# We use the `statsbombpy` library, which provides a **Pythonic interface** to interact with StatsBomb's open-data GitHub repository. It abstracts the underlying JSON structure and URL handling, allowing straightforward access to competitions, matches, events, and lineups through simple function calls.

# %%
import pandas as pd
from statsbombpy import sb

# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)

from src.constants import *

# %%
# to suppress Authentication warnings
from statsbombpy.api_client import NoAuthWarning
import warnings
warnings.filterwarnings("ignore", category=NoAuthWarning)

# %%
# for better visibility and showing all the columns
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### 1. Competitions Data

# %%
# Load and Filter Competitions
competitions = sb.competitions()

# Filter: keep only male competitions
competitions = competitions[competitions['competition_gender']=='male'].sort_values('season_name', ascending=False)

# Filter: keep seasons from 2014 onward
competitions = competitions[competitions['season_name']>'2014']

# Filter: exclude Indian Super League
competitions = competitions[competitions['competition_name']!='Indian Super league']

# %%
# Drop unnecessary columns
competitions.drop(COMPETITIONS_COLUMNS_DROP,
                  axis=1,
                  inplace=True)

# Reset index after filtering
competitions.reset_index(drop=True,
                         inplace=True)

# %%
competitions
# Out:
#     competition_id  season_id              country_name  \
# 0              223        282             South America
# 1               55        282                    Europe
# 2                9        281                   Germany
# 3               44        107  United States of America
# 4             1267        107                    Africa
# 5                7        235                    France
# 6               43        106             International
# 7                7        108                    France
# 8               11         90                     Spain
# 9               55         43                    Europe
# 10              11         42                     Spain
# 11              11          4                     Spain
# 12              16          4                    Europe
# 13              43          3             International
# 14              16          1                    Europe
# 15              11          1                     Spain
# 16              11          2                     Spain
# 17              16          2                    Europe
# 18               2         27                   England
# 19               9         27                   Germany
# 20              11         27                     Spain
# 21               7         27                    France
# 22              16         27                    Europe
# 23              12         27                     Italy
# 24              16         26                    Europe
# 25              11         26                     Spain
#
#           competition_name  competition_international season_name
# 0             Copa America                       True        2024
# 1                UEFA Euro                       True        2024
# 2            1. Bundesliga                      False   2023/2024
# 3      Major League Soccer                      False        2023
# 4   African Cup of Nations                       True        2023
# 5                  Ligue 1                      False   2022/2023
# 6           FIFA World Cup                       True        2022
# 7                  Ligue 1                      False   2021/2022
# 8                  La Liga                      False   2020/2021
# 9                UEFA Euro                       True        2020
# 10                 La Liga                      False   2019/2020
# 11                 La Liga                      False   2018/2019
# 12        Champions League                      False   2018/2019
# 13          FIFA World Cup                       True        2018
# 14        Champions League                      False   2017/2018
# 15                 La Liga                      False   2017/2018
# 16                 La Liga                      False   2016/2017
# 17        Champions League                      False   2016/2017
# 18          Premier League                      False   2015/2016
# 19           1. Bundesliga                      False   2015/2016
# 20                 La Liga                      False   2015/2016
# 21                 Ligue 1                      False   2015/2016
# 22        Champions League                      False   2015/2016
# 23                 Serie A                      False   2015/2016
# 24        Champions League                      False   2014/2015
# 25                 La Liga                      False   2014/2015

# %% [markdown]
# We end up with 26 leagues across various competitions

# %%
competitions.to_csv('../data/competitions.csv', index=False)

# %% [markdown]
# ### 2. Matches

# %%
def get_matches(competitions : pd.DataFrame):

    df_matches = pd.DataFrame()
    
    for i in range(0, len(competitions)):
        competition_id, season_id = competitions.loc[i, ['competition_id', 'season_id']]
        if df_matches.empty:
            df_matches = sb.matches(competition_id=competition_id,
                                    season_id=season_id)
        else:
            df_matches = pd.concat([df_matches,
                                    sb.matches(competition_id=competition_id, season_id=season_id)])
    df_matches.reset_index(drop=True,
                           inplace=True)
    
    df_matches.drop(MATCHES_COLUMNS_DROP,
                    axis=1,
                    inplace=True)
    
    return df_matches

# %%
df_matches = get_matches(competitions)
df_matches
# Out:
#       match_id  match_date      kick_off                   competition  \
# 0      3943077  2024-07-15  04:15:00.000  South America - Copa America
# 1      3943076  2024-07-14  03:00:00.000  South America - Copa America
# 2      3942852  2024-07-11  03:00:00.000  South America - Copa America
# 3      3942785  2024-07-10  03:00:00.000  South America - Copa America
# 4      3942416  2024-07-07  01:00:00.000  South America - Copa America
# ...        ...         ...           ...                           ...
# 2445    266871  2015-02-08  21:00:00.000               Spain - La Liga
# 2446    266967  2015-03-14  18:00:00.000               Spain - La Liga
# 2447    266929  2015-04-05  21:00:00.000               Spain - La Liga
# 2448    266770  2014-09-21  21:00:00.000               Spain - La Liga
# 2449    266142  2015-04-11  20:00:00.000               Spain - La Liga
#
#          season      home_team  away_team  home_score  away_score  match_week  \
# 0          2024      Argentina   Colombia           1           0           6
# 1          2024         Canada    Uruguay           2           2           6
# 2          2024        Uruguay   Colombia           0           1           5
# 3          2024      Argentina     Canada           2           0           5
# 4          2024       Colombia     Panama           5           0           4
# ...         ...            ...        ...         ...         ...         ...
# 2445  2014/2015  Athletic Club  Barcelona           2           5          22
# 2446  2014/2015          Eibar  Barcelona           0           2          27
# 2447  2014/2015     Celta Vigo  Barcelona           0           1          29
# 2448  2014/2015     Levante UD  Barcelona           0           5           4
# 2449  2014/2015        Sevilla  Barcelona           2           2          31
#
#      competition_stage                        stadium  \
# 0                Final              Hard Rock Stadium
# 1      3rd Place Final        Bank of America Stadium
# 2          Semi-finals        Bank of America Stadium
# 3          Semi-finals                MetLife Stadium
# 4       Quarter-finals             State Farm Stadium
# ...                ...                            ...
# 2445    Regular Season               San Mamés Barria
# 2446    Regular Season    Estadio Municipal de Ipurúa
# 2447    Regular Season                Abanca-Balaídos
# 2448    Regular Season     Estadio Ciudad de Valencia
# 2449    Regular Season  Estadio Ramón Sánchez Pizjuán
#
#                             referee                    home_managers  \
# 0                     Raphael Claus         Lionel Sebastián Scaloni
# 1                    Alexis Herrera                     Jesse Marsch
# 2     César Arturo Ramos Palazuelos   Marcelo Alberto Bielsa Caldera
# 3                  Piero Maza Gomez         Lionel Sebastián Scaloni
# 4                  Maurizio Mariani           Néstor Gabriel Lorenzo
# ...                             ...                              ...
# 2445     Antonio Miguel Mateu Lahoz         Ernesto Valverde Tejedor
# 2446                            NaN          Gaizka Garitano Aguirre
# 2447                            NaN           Manuel Eduardo Berizzo
# 2448    José Luis González González  José Luis Mendilibar Etxebarria
# 2449                            NaN             Unai Emery Etxegoien
#
#                        away_managers data_version
# 0             Néstor Gabriel Lorenzo        1.1.0
# 1     Marcelo Alberto Bielsa Caldera        1.1.0
# 2             Néstor Gabriel Lorenzo        1.1.0
# 3                       Jesse Marsch        1.1.0
# 4          Thomas Christiansen Tarín        1.1.0
# ...                              ...          ...
# 2445    Luis Enrique Martínez García        1.1.0
# 2446    Luis Enrique Martínez García        1.1.0
# 2447    Luis Enrique Martínez García        1.1.0
# 2448    Luis Enrique Martínez García        1.1.0
# 2449    Luis Enrique Martínez García        1.1.0
#
# [2450 rows x 16 columns]
